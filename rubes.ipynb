# %%
# how many were from the south?
# an unsoiphsticated person from a rural area; hick
# how many went to college?  how prestigious were those colleges?
# how many were from small towns?

# %%
import pandas as pd
import os.path
import matplotlib.pyplot as plt
import numpy as np

# %%
people_csv = os.path.join("Resources", "baseballdatabank-master", "core", "People.csv")
# college_csv = os.path.join("Resources", "baseballdatabank-master", "core", "People.csv")

people_df = pd.read_csv(people_csv)
people_df.head(5)
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay  ... nameLast       nameGiven  \
# 0      Denver        NaN         NaN       NaN  ...  Aardsma     David Allan
# 1      Mobile     2021.0         1.0      22.0  ...    Aaron     Henry Louis
# 2      Mobile     1984.0         8.0      16.0  ...    Aaron      Tommie Lee
# 3      Orange        NaN         NaN       NaN  ...     Aase  Donald William
# 4  Palm Beach        NaN         NaN       NaN  ...     Abad   Fausto Andres
#
#   weight height bats throws       debut   finalGame   retroID    bbrefID
# ...

# %%
rubes_df = people_df.loc[(people_df["nameFirst"] == "Rube")]

# %%
rubes_df.columns
# Out:
# Index(['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay',
#        'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID'],
#       dtype='object')

# %%
columns = ["playerID", "nameFirst", "nameLast", "nameGiven", "birthCity", "birthState", "birthYear", "deathCity", "deathState", "deathYear"]
rubes_df[columns]
# Out:
#         playerID nameFirst  nameLast         nameGiven      birthCity  \
# 1277   bentoru01      Rube    Benton       John Cleave        Clinton
# 1997   bressru01      Rube  Bressler     Raymond Bloom          Coder
# 4413   degroru01      Rube   DeGroff    Arthur Sleight      Hyde Park
# 4560   dessaru01      Rube    Dessau     Frank Rolland    New Galilee
# 5211   ehrharu01      Rube  Ehrhardt     Welton Claude        Beecher
# 5272   ellisru01      Rube     Ellis    George William         Downey
# 5725   fischru01      Rube   Fischer     Reuben Walter        Carlock
# 5964   fosteru01      Rube    Foster            George         Lehigh
# 5965   fosteru99      Rube    Foster     Andrew Bishop      La Grange
# 6540   geyerru01      Rube     Geyer      Jacob Bowman      Allegheny
# 9772   kisinru01      Rube  Kisinger    Charles Samuel         Adrian
# 10026   krohru01      Rube      Kroh       Floyd Myron     Friendship
# ...

# %%
#largely a nickname given to northerners?
rubes_df["birthState"].value_counts()
# Out:
# PA    8
# NC    3
# NY    3
# IL    3
# OH    3
# MI    2
# CA    1
# SD    1
# OK    1
# TX    1
# WI    1
# DE    1
# MN    1
# Name: birthState, dtype: int64

# %%
rubes_birthyear = pd.Series(rubes_df["birthYear"])
rubes_birthyear
# Out:
# 1277     1890.0
# 1997     1894.0
# 4413     1879.0
# 4560     1883.0
# 5211     1894.0
# 5272     1885.0
# 5725     1916.0
# 5964     1888.0
# 5965     1879.0
# 6540     1884.0
# 9772     1876.0
# 10026    1886.0
# 10974    1897.0
# 11266    1883.0
# 11354    1886.0
# 11382    1890.0
# 12219    1917.0
# 13465    1924.0
# 13618    1884.0
# 13995    1894.0
# 14349    1885.0
# 16306    1891.0
# 16575    1881.0
# 18931    1879.0
# 18963    1879.0
# 19020    1876.0
# 19068    1896.0
# 19111    1926.0
# 19223    1879.0
# 20153    1896.0
# Name: birthYear, dtype: float64

# %%
# # create bins for segmenting schools based on per capita budget
# spending_bins = [0, 585, 630, 645, 675]
# group_names = ["<$584", "$585-629", "$630-644", "$645-675"]
# # create segment data using cut() and then identify schools in buckets using groupby() and count()
# per_school_capita.groupby(pd.cut(per_school_capita, spending_bins)).count()
# per_school_results_df["Spending Ranges (Per Student)"] = pd.cut(per_school_capita, spending_bins, labels=group_names)

rubes_birthyear.describe()
# Out:
# count      30.000000
# mean     1890.566667
# std        13.584178
# min      1876.000000
# 25%      1881.500000
# 50%      1886.000000
# 75%      1894.000000
# max      1926.000000
# Name: birthYear, dtype: float64

# %%
year_bins = np.arange(1875,1931,step=5.0)
group_names = [
    "1876-1880",
    "1881-1885",
    "1886-1890",
    "1891-1895",
    "1896-1900",
    "1901-1905",
    "1906-1910",    
    "1911-1915",
    "1916-1920",
    "1921-1925",
    "1926-1930"
]

rubes_range = pd.cut(rubes_birthyear, year_bins, labels=group_names)
# Out:
# 1277     1886-1890
# 1997     1891-1895
# 4413     1876-1880
# 4560     1881-1885
# 5211     1891-1895
# 5272     1881-1885
# 5725     1916-1920
# 5964     1886-1890
# 5965     1876-1880
# 6540     1881-1885
# 9772     1876-1880
# 10026    1886-1890
# 10974    1896-1900
# 11266    1881-1885
# 11354    1886-1890
# 11382    1886-1890
# 12219    1916-1920
# 13465    1921-1925
# 13618    1881-1885
# 13995    1891-1895
# 14349    1881-1885
# 16306    1891-1895
# 16575    1881-1885
# 18931    1876-1880
# 18963    1876-1880
# 19020    1876-1880
# 19068    1896-1900
# 19111    1926-1930
# 19223    1876-1880
# 20153    1896-1900
# Name: birthYear, dtype: category
# Categories (11, object): ['1876-1880' < '1881-1885' < '1886-1890' < '1891-1895' ... '1911-1915' < '1916-1920' < '1921-1925' < '1926-1930']

# %%
rubes_range_rollup = rubes_range.groupby(group_names).count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9912/2572481358.py in <module>
# ----> 1 rubes_range_rollup = rubes_range.groupby(group_names).count()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1892             squeeze=squeeze,  # type: ignore[arg-type]
#    1893             observed=observed,
# -> 1894             dropna=dropna,
#    1895         )
#    1896
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     895                 observed=observed,
#     896                 mutated=self.mutated,
# --> 897                 dropna=self.dropna,
# ...
