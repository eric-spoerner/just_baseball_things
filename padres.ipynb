# %%
import pandas as pd
import os.path
import matplotlib.pyplot as plt
import numpy as np

# %%
teams_csv = os.path.join("Resources", "baseballdatabank-master", "core", "Teams.csv")


teams_df = pd.read_csv(teams_csv)
teams_df.head(5)
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP     FP  \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ...  24  0.834
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9  ...  16  0.829
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19  ...  15  0.818
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12  ...   8  0.803
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17  ...  14  0.840
#
#                       name                          park  attendance  BPF  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
# 3     Fort Wayne Kekiongas                Hamilton Field         NaN  101
# 4         New York Mutuals      Union Grounds (Brooklyn)         NaN   90
#
#    PPF  teamIDBR  teamIDlahman45  teamIDretro
# ...

# %%
people_csv = os.path.join("Resources", "baseballdatabank-master", "core", "People.csv")

people_df = pd.read_csv(people_csv)
people_df.columns
# Out:
# Index(['playerID', 'birthYear', 'birthMonth', 'birthDay', 'birthCountry',
#        'birthState', 'birthCity', 'deathYear', 'deathMonth', 'deathDay',
#        'deathCountry', 'deathState', 'deathCity', 'nameFirst', 'nameLast',
#        'nameGiven', 'weight', 'height', 'bats', 'throws', 'debut', 'finalGame',
#        'retroID', 'bbrefID'],
#       dtype='object')

# %%
teams_df.loc[(teams_df["franchID"] == "SDP")]
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome   W    L  ...   DP  \
# 1536    1969   NL    SDN      SDP     W     6  162   81.0  52  110  ...  140
# 1561    1970   NL    SDN      SDP     W     6  162   81.0  63   99  ...  159
# 1585    1971   NL    SDN      SDP     W     6  161   81.0  61  100  ...  144
# 1609    1972   NL    SDN      SDP     W     6  153   80.0  58   95  ...  146
# 1633    1973   NL    SDN      SDP     W     6  162   81.0  60  102  ...  152
# 1657    1974   NL    SDN      SDP     W     6  162   81.0  60  102  ...  126
# 1681    1975   NL    SDN      SDP     W     4  162   81.0  71   91  ...  163
# 1705    1976   NL    SDN      SDP     W     5  162   80.0  73   89  ...  148
# 1729    1977   NL    SDN      SDP     W     5  162   81.0  69   93  ...  142
# 1755    1978   NL    SDN      SDP     W     4  162   81.0  84   78  ...  171
# 1781    1979   NL    SDN      SDP     W     5  161   81.0  68   93  ...  154
# ...

# %%
teams_df.columns
# teams_df["teamID","franchID"]
# Out:
# Index(['yearID', 'lgID', 'teamID', 'franchID', 'divID', 'Rank', 'G', 'Ghome',
#        'W', 'L', 'DivWin', 'WCWin', 'LgWin', 'WSWin', 'R', 'AB', 'H', '2B',
#        '3B', 'HR', 'BB', 'SO', 'SB', 'CS', 'HBP', 'SF', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'IPouts', 'HA', 'HRA', 'BBA', 'SOA', 'E', 'DP', 'FP',
#        'name', 'park', 'attendance', 'BPF', 'PPF', 'teamIDBR',
#        'teamIDlahman45', 'teamIDretro'],
#       dtype='object')
